# %% [markdown]
# # Covid 19 Demo with Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('./full_grouped.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Country/Region','Deaths', 'Active']]
# Out:
#            Country/Region  Deaths  Active
# 0             Afghanistan       0       0
# 1                 Albania       0       0
# 2                 Algeria       0       0
# 3                 Andorra       0       0
# 4                  Angola       0       0
# ...                   ...     ...     ...
# 35151  West Bank and Gaza      78    6791
# 35152      Western Sahara       1       1
# 35153               Yemen     483     375
# 35154              Zambia     140    1597
# 35155            Zimbabwe      36    2126
#
# [35156 rows x 3 columns]

# %%
df.head(5)
# Out:
#          Date Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0  2020-01-22    Afghanistan          0       0          0       0          0
# 1  2020-01-22        Albania          0       0          0       0          0
# 2  2020-01-22        Algeria          0       0          0       0          0
# 3  2020-01-22        Andorra          0       0          0       0          0
# 4  2020-01-22         Angola          0       0          0       0          0
#
#    New deaths  New recovered             WHO Region
# 0           0              0  Eastern Mediterranean
# 1           0              0                 Europe
# 2           0              0                 Africa
# 3           0              0                 Europe
# 4           0              0                 Africa

# %%
df.tail(10)
# Out:
#              Date      Country/Region  Confirmed  Deaths  Recovered  Active  \
# 35146  2020-07-27      United Kingdom     301708   45844       1437  254427
# 35147  2020-07-27             Uruguay       1202      35        951     216
# 35148  2020-07-27          Uzbekistan      21209     121      11674    9414
# 35149  2020-07-27           Venezuela      15988     146       9959    5883
# 35150  2020-07-27             Vietnam        431       0        365      66
# 35151  2020-07-27  West Bank and Gaza      10621      78       3752    6791
# 35152  2020-07-27      Western Sahara         10       1          8       1
# 35153  2020-07-27               Yemen       1691     483        833     375
# 35154  2020-07-27              Zambia       4552     140       2815    1597
# 35155  2020-07-27            Zimbabwe       2704      36        542    2126
#
#        New cases  New deaths  New recovered             WHO Region
# ...

# %%
df.iloc[88]
# Out:
# Date                         2020-01-22
# Country/Region                   Jordan
# Confirmed                             0
# Deaths                                0
# Recovered                             0
# Active                                0
# New cases                             0
# New deaths                            0
# New recovered                         0
# WHO Region        Eastern Mediterranean
# Name: 88, dtype: object

# %%
df['New cases']
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#         ...
# 35151    152
# 35152      0
# 35153     10
# 35154     71
# 35155    192
# Name: New cases, Length: 35156, dtype: int64

# %%
df['New cases'].sum()
# Out:
# 16500952

# %%
df['Recovered'].mean() # average
# Out:
# 11048.134856070088

# %%
jordan_data = df[ df['Country/Region']=='Jordan' ] # All Jordan data

# %%
jordan_new_cases = jordan_data['New cases'] # Only 'New cases' column

# %%
average_new_cases_Jordan = jordan_new_cases.mean() # Calculate the mean

# %%
average_new_cases_Jordan
# Out:
# 6.840425531914893

# %%
#Alternative way
df[ df['Country/Region']=='Jordan' ]['New cases'].mean()
# Out:
# 6.840425531914893

# %%
# All data for Jordan where new cases > 20
jordan_data[jordan_data['New cases'] > 20]
# df[ df['New cases'] > 20 ]
# Out:
#              Date Country/Region  Confirmed  Deaths  Recovered  Active  \
# 11308  2020-03-22         Jordan        112       0          1     111
# 11682  2020-03-24         Jordan        154       0          1     153
# 12056  2020-03-26         Jordan        212       0          1     211
# 12243  2020-03-27         Jordan        235       1         18     216
# 13365  2020-04-02         Jordan        299       5         45     249
# 13926  2020-04-05         Jordan        345       5        110     230
# 19910  2020-05-07         Jordan        494       9        381     104
# 20658  2020-05-11         Jordan        562       9        390     163
# 22341  2020-05-20         Jordan        672       9        446     217
# 25894  2020-06-08         Jordan        831       9        627     195
# 26455  2020-06-11         Jordan        890       9        670     211
# 26642  2020-06-12         Jordan        915       9        671     235
# ...

# %%
jordan_data[ jordan_data['New deaths'] > 1]
# Out:
#              Date Country/Region  Confirmed  Deaths  Recovered  Active  \
# 12617  2020-03-29         Jordan        259       3         18     238
# 12804  2020-03-30         Jordan        268       5         26     237
#
#        New cases  New deaths  New recovered             WHO Region
# 12617         13           2              0  Eastern Mediterranean
# 12804          9           2              8  Eastern Mediterranean

# %%
jordan_data[ jordan_data['Confirmed'] >300 ][jordan_data['New cases']>15].sort_values('Active', ascending=False)
# Out:
# <ipython-input-18-a20610340e52>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   jordan_data[ jordan_data['Confirmed'] >300 ][jordan_data['New cases']>15].sort_values('Active', ascending=False)
#              Date Country/Region  Confirmed  Deaths  Recovered  Active  \
# 28325  2020-06-21         Jordan       1033       9        739     285
# 28886  2020-06-24         Jordan       1071       9        782     280
# 27203  2020-06-15         Jordan        979       9        692     278
# 26829  2020-06-13         Jordan        953       9        678     266
# 29260  2020-06-26         Jordan       1104       9        830     265
# 26642  2020-06-12         Jordan        915       9        671     235
# 22715  2020-05-22         Jordan        700       9        461     230
# 13926  2020-04-05         Jordan        345       5        110     230
# 22154  2020-05-19         Jordan        649       9        417     223
# ...

# %%
# Average number of deaths in Jordan when the confirmed cases were > 300 and the daily new cases were > 15
jordan_data[ jordan_data['Confirmed'] >300 ][jordan_data['New cases']>15]['Deaths'].mean()
# Out:
# <ipython-input-19-231e355a30f3>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   jordan_data[ jordan_data['Confirmed'] >300 ][jordan_data['New cases']>15]['Deaths'].mean()
# 8.777777777777779

# %%
# Standard Deviation of deaths in Jordan when the confirmed cases were > 300 and the daily new cases were > 15
jordan_data[ jordan_data['Confirmed'] >300 ][jordan_data['New cases']>15]['Deaths'].std()
# Out:
# <ipython-input-24-0bbbbcf0865b>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   jordan_data[ jordan_data['Confirmed'] >300 ][jordan_data['New cases']>15]['Deaths'].std()
# 0.9428090415820634

# %%
# Average of every number combined for each country
combined_data = df.groupby('Country/Region').mean()

# %%
combined_data
# Out:
#                        Confirmed      Deaths    Recovered       Active  \
# Country/Region
# Afghanistan         10299.946809  261.159574  4245.957447  5792.829787
# Albania              1046.287234   30.361702   632.324468   383.601064
# Algeria              6275.292553  414.744681  4020.728723  1839.819149
# Andorra               502.148936   28.845745   367.414894   105.888298
# Angola                120.542553    5.734043    34.962766    79.845745
# ...                          ...         ...          ...          ...
# West Bank and Gaza   1241.813830    7.287234   325.127660   909.398936
# Western Sahara          4.792553    0.335106     3.446809     1.010638
# Yemen                 357.340426   94.186170   126.484043   136.670213
# Zambia                688.409574   14.058511   444.739362   229.611702
# Zimbabwe              270.180851    4.686170    64.930851   200.563830
#
#                      New cases  New deaths  New recovered
# Country/Region
# ...

# %%
# The top 5 country in number of new cases where number of deaths > 1000 sorted by number of confirmed cases decending
top_deaths = combined_data[combined_data['Deaths']>1000].sort_values('New cases', ascending=True).tail(5).sort_values('Confirmed', ascending=False)

# %%
top_deaths[['Deaths','New cases','Confirmed']]
# Out:
#                       Deaths     New cases     Confirmed
# Country/Region
# US              58571.335106  22820.521277  1.193330e+06
# Brazil          20946.989362  12991.356383  4.761966e+05
# Russia           3294.601064   4344.042553  2.415341e+05
# India            5913.994681   7872.728723  2.174652e+05
# Mexico           9192.962766   2103.664894  7.950107e+04
